# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %run graphy_v2.py
# Out:
# Figure will be saved as: Data/TrackImages/Actb.pdf
# ======
# Regions
# ======
# miR-1-3p/206-3p [142903471, 142903478]
# miR-124-3p.2 [142903299, 142903306]
# miR-145-5p [142903597, 142903605]
# miR-205-5p [142903216, 142903223]

# %%
track_names = [f for f in w_antisense_check.options if f.split(".")[-1]=="bam"]
track_files = [w_default_folder.value + f for f in track_names]

# %%
import os

# %%
track_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-26f2f9c6fb0d> in <module>()
# ----> 1 track_files
#
# NameError: name 'track_files' is not defined
